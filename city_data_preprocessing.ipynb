# %% [markdown]
# The goal of this workbook is to end with our city dataset which I will use for analysis. It will include 4 different sources of data.
#
# City Dataset
# - 2013 city GHG emissions per capita
# - 2017 Mayoral support (signature) for Paris climate agreement
# - 2000-2011 City Partisan index
# - Mayoral political party (for a mayor that had the opportunity to sign support for paris)

# %% [markdown]
# Import Modules

# %%
from os import path
import requests
from bs4 import BeautifulSoup as Soup
from urllib.request import Request, urlopen
from pandas import DataFrame
import pandas as pd
import numpy as np
import math
DATA_DIR = '/Users/joeskvarna/Desktop/Thesis/Data'
#pd.set_option('display.max_rows', None)
#pd.set_option('max_rows', 5)

# %% [markdown]
# # 1. GHG emissions Per Capita

# %% [markdown]
# Open txt file from source and take a look

# %%
city = pd.read_csv(path.join(DATA_DIR, 'city_ghg_source.txt'), sep =  '\t')
city.head()
# Out:
#              Urban Cluster    Country  Population  Footprint (Mt CO2)  \
# 0            Hong Kong SAR      China     6029000                 NaN
# 1  Mohammed Bin Zayed City        UAE      188000                 NaN
# 2                Abu Dhabi        UAE      911000                 NaN
# 3     Country of Singapore  Singapore     5235000                 NaN
# 4               Hulun Buir      China      198000                 NaN
#
#    1StdDev Footprint/Cap (t CO2/cap)  ClusterID  Global ranking
# 0     37.8          34.6 &plusmn;6.3      13847               1
# 1      5.3         32.9 &plusmn;27.9       5292               2
# 2     15.6         32.9 &plusmn;17.1       5288               3
# 3     34.1          30.8 &plusmn;6.5      13845               4
# 4      6.4         30.0 &plusmn;32.3      10441               5

# %% [markdown]
# select only cities from the US

# %%
city_us = city.loc[city['Country'] == 'USA']
city_us = city_us.reset_index(drop=True)
city_us.sample(10)
# Out:
#                            Urban Cluster Country  Population  \
# 75                                 Miami     USA     5031000
# 62                                 Salem     USA      150000
# 108  Unknown city at lat/lon 27.3, -80.4     USA      170000
# 52                              San Jose     USA     4003000
# 63                              Portland     USA     1163000
# 66                              Columbia     USA      177000
# 65                             Allentown     USA      359000
# 3                              St. Louis     USA     1177000
# 32                               Buffalo     USA      570000
# 82                          Palm Springs     USA      299000
#
#      Footprint (Mt CO2)  1StdDev Footprint/Cap (t CO2/cap)  ClusterID  \
# 75                  NaN     21.9          16.0 &plusmn;4.4        513
# 62                  NaN      1.7         16.8 &plusmn;11.4         95
# 108                 NaN      0.8           9.2 &plusmn;5.0        550
# 52                  NaN     19.7          17.5 &plusmn;4.9         11
# 63                  NaN      9.3          16.7 &plusmn;8.0        104
# 66                  NaN      1.6          16.6 &plusmn;8.9        637
# 65                  NaN      3.4          16.6 &plusmn;9.5        837
# 3                   NaN      9.6          24.1 &plusmn;8.2        448
# 32                  NaN      5.7         19.8 &plusmn;10.0      16274
# 82                  NaN      2.3          15.4 &plusmn;7.5         61
#
#      Global ranking
# 75              119
# 62               97
# 108             471
# 52               85
# 63              102
# 66              106
# 65              104
# 3                19
# 32               56
# 82              131

# %% [markdown]
# Some cities specificy their state with ",MA" for example. We want to remove this to keep name format consistent

# %%
city_us["Urban Cluster"] = city_us["Urban Cluster"].str.replace(r',[^,]*$', '')
city_us.sample(10)
# Out:
# <ipython-input-38-45e02f0c8557>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   city_us["Urban Cluster"] = city_us["Urban Cluster"].str.replace(r',[^,]*$', '')
#                     Urban Cluster Country  Population  Footprint (Mt CO2)  \
# 53                      Rochester     USA      306000                 NaN
# 91                        El Paso     USA      463000                 NaN
# 37                       Hartford     USA      568000                 NaN
# 67                 Corpus Christi     USA      179000                 NaN
# 6                     Kansas City     USA     1004000                 NaN
# 25                         Naples     USA      200000                 NaN
# 26                      Milwaukee     USA      821000                 NaN
# 90                    Los Angeles     USA    13482000                 NaN
# 104  Unknown city at lat/lon 40.3     USA      253000                 NaN
# 17                     Burnsville     USA      152000                 NaN
#
#      1StdDev Footprint/Cap (t CO2/cap)  ClusterID  Global ranking
# 53       4.2         17.5 &plusmn;13.9        836              86
# 91       4.0          14.6 &plusmn;8.5      14661             159
# 37       5.9         19.0 &plusmn;10.4        904              63
# 67       1.8         16.6 &plusmn;10.2        254             107
# 6        7.4          22.6 &plusmn;7.4        386              23
# 25       2.5         20.5 &plusmn;12.4        471              46
# 26       7.3          20.4 &plusmn;8.9        628              47
# 90      43.7          14.6 &plusmn;3.2         15             158
# 104      2.1          11.0 &plusmn;8.2        193             330
# 17       2.0         21.2 &plusmn;12.9        521              37

# %% [markdown]
# This is good fo now, we will bring in our other data

# %% [markdown]
# # 2. Mayoral support for Paris Climate Agreement

# %% [markdown]
# This data is taken from a website. We will scrape the data from this site.

# %%
url = 'https://climatemayors.org/actions-paris-climate-agreement'
def scraper(url):
    req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    webpage = urlopen(req).read()

    page_soup = Soup(webpage, 'html.parser')
    return page_soup
page_soup = scraper(url)

# %% [markdown]
# Look at a list of all the paragraph tags on the website

# %%
p = page_soup.find_all('p')
print(p[:10])
print(p[-10:])
# Out:
# [<p>STATEMENT FROM THE CLIMATE MAYORS IN RESPONSE TO PRESIDENT TRUMP’S WITHDRAWAL FROM THE PARIS CLIMATE AGREEMENT</p>, <p>The President’s denial of global warming is getting a cold reception from America’s cities.</p>, <p>As 466 US Mayors representing 74 million Americans, we will adopt, honor, and uphold the commitments to the goals enshrined in the Paris Agreement. We will intensify efforts to meet each of our cities’ current climate goals, push for new action to meet the 1.5 degrees Celsius target, and work together to create a 21st century clean energy economy.</p>, <p>We will continue to lead. We are increasing investments in renewable energy and energy efficiency. We will buy and create more demand for electric cars and trucks. We will increase our efforts to cut greenhouse gas emissions, create a clean energy economy, and stand for environmental justice. And if the President wants to break the promises made to our allies enshrined in the historic Paris Agreement, we’ll build and strengthen relationships around the world to protect the planet from devastating climate risks.</p>, <p>The world cannot wait — and neither will we.</p>, <p>Signed,</p>, <p>Mayor Trish Herrera Spencer<br/>
# City of Alameda, CA</p>, <p>Mayor Peggy McQuaid<br/>
# City of Albany, CA</p>, <p>Mayor Sharon Konopa<br/>
# City of Albany, OR</p>, <p>Mayor Kathy Sheehan<br/>
# City of Albany, NY</p>]
# [<p>Mayor Allen Joines<br/>
# City of Winston Salem, NC</p>, <p>Mayor Xóchitl Rodríguez<br/>
# City of Woodland, CA</p>, <p>Mayor Daniel Yost<br/>
# City of Woodside, CA</p>, <p>Mayor Brian Sager<br/>
# City of Woodstock, IL</p>, <p>Mayor Joseph M. Petty<br/>
# City of Worcester, MA</p>, <p>Mayor Mike Spano<br/>
# City of Yonkers, NY</p>, <p>Mayor Jamael Tito Brown<br/>
# City of Youngstown, OH</p>, <p>Mayor Lois Richardson<br/>
# City of Ypsilanti, MI</p>, <p><em>The <a href="https://medium.com/@ClimateMayors/climate-mayors-commit-to-adopt-honor-and-uphold-paris-climate-agreement-goals-ba566e260097">statement</a> was originally released on June 1, 2017 with 61 signatories. Updated signatories as of 3:00 pm PT on November 27, 2019.</em></p>, <p><a href="mailto:INFO@CLIMATE-MAYORS.ORG">INFO@CLIMATE-MAYORS.ORG</a></p>]

# %% [markdown]
# For each p tag with city and mayor, split the lines to separate city and mayor

# %%
split_list = [str(x).splitlines() for x in p[6:-2]]
split_list[:5]
# Out:
# [['<p>Mayor Trish Herrera Spencer<br/>', 'City of Alameda, CA</p>'],
#  ['<p>Mayor Peggy McQuaid<br/>', 'City of Albany, CA</p>'],
#  ['<p>Mayor Sharon Konopa<br/>', 'City of Albany, OR</p>'],
#  ['<p>Mayor Kathy Sheehan<br/>', 'City of Albany, NY</p>'],
#  ['<p>Mayor Tim Keller<br/>', 'City of Albuquerque, NM</p>']]

# %% [markdown]
# create a dataframe from our list

# %%
mayor_paris = pd.DataFrame(split_list)
mayor_paris.head()
# Out:
#                                      0                            1
# 0  <p>Mayor Trish Herrera Spencer<br/>      City of Alameda, CA</p>
# 1          <p>Mayor Peggy McQuaid<br/>       City of Albany, CA</p>
# 2          <p>Mayor Sharon Konopa<br/>       City of Albany, OR</p>
# 3          <p>Mayor Kathy Sheehan<br/>       City of Albany, NY</p>
# 4             <p>Mayor Tim Keller<br/>  City of Albuquerque, NM</p>

# %% [markdown]
# rename columns

# %%
mayor_paris = mayor_paris.rename({0:'mayor_name', 1:'mayor_city'}, axis = 1)
mayor_paris.head()
# Out:
#                             mayor_name                   mayor_city
# 0  <p>Mayor Trish Herrera Spencer<br/>      City of Alameda, CA</p>
# 1          <p>Mayor Peggy McQuaid<br/>       City of Albany, CA</p>
# 2          <p>Mayor Sharon Konopa<br/>       City of Albany, OR</p>
# 3          <p>Mayor Kathy Sheehan<br/>       City of Albany, NY</p>
# 4             <p>Mayor Tim Keller<br/>  City of Albuquerque, NM</p>

# %% [markdown]
# Remove the tags from each column and adjust for 3 differently spelled columns from the GHG emissions dataset to make for a succesful merge

# %%
if len(mayor_paris['mayor_city'][0]) >= 12:
    mayor_paris['mayor_name'] = mayor_paris['mayor_name'].str[9:-5]
    mayor_paris['mayor_city'] = mayor_paris['mayor_city'].str[8:-4]
    
if mayor_paris.at[292, 'mayor_city'] != 'New York, NY':
    mayor_paris.at[292, 'mayor_city'] = 'New York, NY'
    
if mayor_paris.at[434, 'mayor_city'] != 'Washington D.C., DC':
    mayor_paris.at[434, 'mayor_city'] = 'Washington D.C., DC'

if mayor_paris.at[396, 'mayor_city'] != 'St. Louis, MO':
    mayor_paris.at[396, 'mayor_city'] = 'St. Louis, MO'

mayor_paris.head(10)
# Out:
#               mayor_name       mayor_city
# 0  Trish Herrera Spencer      Alameda, CA
# 1          Peggy McQuaid       Albany, CA
# 2          Sharon Konopa       Albany, OR
# 3          Kathy Sheehan       Albany, NY
# 4             Tim Keller  Albuquerque, NM
# 5          Justin Wilson   Alexandria, VA
# 6          Ray O’Connell    Allentown, PA
# 7            Jeanne Sorg       Ambler, PA
# 8           Gary Goosman    Amesville, OH
# 9          Gavin Buckley    Annapolis, MD

# %% [markdown]
# # 3. City Partisan Index

# %% [markdown]
# read the csv file from the study

# %%
city_partisan = pd.read_csv(path.join(DATA_DIR, 'city_partisan_index.csv'))
city_partisan.head()
# Out:
#                    City  Conservatism
# 0              Mesa, AZ          0.41
# 1     Oklahoma City, OK          0.26
# 2    Virginia Beach, VA          0.25
# 3  Colorado Springs, CO          0.23
# 4      Jacksonville, FL          0.18

# %% [markdown]
# this is all we need to do with this one right now

# %% [markdown]
# # 4. Merge 1-3

# %% [markdown]
# ## Review datasets 1-3

# %% [markdown]
# 1. GHG Emissions per capita as city_us

# %%
city_us.head()
# Out:
#   Urban Cluster Country  Population  Footprint (Mt CO2)  1StdDev  \
# 0   New Orleans     USA      596000                 NaN      7.8
# 1       Detroit     USA     2770000                 NaN     15.4
# 2     Cleveland     USA      973000                 NaN      8.8
# 3     St. Louis     USA     1177000                 NaN      9.6
# 4    Pittsburgh     USA      602000                 NaN      6.3
#
#   Footprint/Cap (t CO2/cap)  ClusterID  Global ranking
# 0         26.1 &plusmn;13.0        373              12
# 1          25.5 &plusmn;5.6      16079              13
# 2          24.7 &plusmn;9.0        726              17
# 3          24.1 &plusmn;8.2        448              19
# 4         24.0 &plusmn;10.4        753              21

# %% [markdown]
# 2. Mayoral Support for Paris Climate Agreement as mayor_paris

# %%
mayor_paris.head()
# Out:
#               mayor_name       mayor_city
# 0  Trish Herrera Spencer      Alameda, CA
# 1          Peggy McQuaid       Albany, CA
# 2          Sharon Konopa       Albany, OR
# 3          Kathy Sheehan       Albany, NY
# 4             Tim Keller  Albuquerque, NM

# %% [markdown]
# 3. City Partisan Index as city_partisan

# %%
city_partisan.head()
# Out:
#                    City  Conservatism
# 0              Mesa, AZ          0.41
# 1     Oklahoma City, OK          0.26
# 2    Virginia Beach, VA          0.25
# 3  Colorado Springs, CO          0.23
# 4      Jacksonville, FL          0.18

# %% [markdown]
# ## 4.1 Combine city_us (GHG emissions per capita) and city_partisan (City Partisan Index)

# %% [markdown]
# Remove the state part of city_partisan

# %%
if len(city_partisan['City'][0]) >= 5:
    city_partisan['City'] = city_partisan['City'].str[:-4]
city_partisan.head()
# Out:
#                City  Conservatism
# 0              Mesa          0.41
# 1     Oklahoma City          0.26
# 2    Virginia Beach          0.25
# 3  Colorado Springs          0.23
# 4      Jacksonville          0.18

# %% [markdown]
# merge both on their respective city column, 'Urban Cluster' and 'City'

# %%
comb_1 = pd.merge(city_us, city_partisan, how='left', left_on = 'Urban Cluster', right_on = 'City')
comb_1.head()
# Out:
#   Urban Cluster Country  Population  Footprint (Mt CO2)  1StdDev  \
# 0   New Orleans     USA      596000                 NaN      7.8
# 1       Detroit     USA     2770000                 NaN     15.4
# 2     Cleveland     USA      973000                 NaN      8.8
# 3     St. Louis     USA     1177000                 NaN      9.6
# 4    Pittsburgh     USA      602000                 NaN      6.3
#
#   Footprint/Cap (t CO2/cap)  ClusterID  Global ranking         City  \
# 0         26.1 &plusmn;13.0        373              12  New Orleans
# 1          25.5 &plusmn;5.6      16079              13      Detroit
# 2          24.7 &plusmn;9.0        726              17    Cleveland
# 3          24.1 &plusmn;8.2        448              19    St. Louis
# 4         24.0 &plusmn;10.4        753              21          NaN
#
#    Conservatism
# 0         -0.51
# 1         -0.73
# 2         -0.42
# 3         -0.52
# 4           NaN

# %% [markdown]
# ### Find values lost in the 1st merge

# %% [markdown]
# Create a list of the Urban Cluster and City column from comb_1 and a list of the city column from the city_partisan table. And check length of all.

# %%
comb_1_city = (comb_1['City'].dropna()).tolist()
comb_1_urban = (comb_1['Urban Cluster'].dropna()).tolist()
city_partisan_city = (city_partisan['City'].dropna()).tolist()
print(len(comb_1_city))
print(len(comb_1_urban))
print(len(city_partisan_city))
# Out:
# 50
# 109
# 67

# %% [markdown]
# Find cities I lost in the merge from city_partisan. It should be 17.

# %%
city_partisan_lost = []
for city in city_partisan_city:
    if city not in comb_1_city:
        city_partisan_lost.append(city)

print(city_partisan_lost)
print(len(city_partisan_lost))
# Out:
# ['Mesa', 'Virginia Beach', 'Arlington', 'Anaheim', 'Aurora', 'Anchorage', 'Fort Worth', 'Lexington', 'Riverside', 'Santa Ana', 'Long Beach', 'Honolulu', 'Newark', 'Pittrburgh', 'St. Paul', 'Washington', 'San Francisco']
# 17

# %% [markdown]
# 17 as we would expect (67-50). We will take note of Pittsburgh and Washington as they are spelled differently. The ghg dataset doesn't have San Francisco so that makes sense.

# %%
comb_1.head()
# Out:
#   Urban Cluster Country  Population  Footprint (Mt CO2)  1StdDev  \
# 0   New Orleans     USA      596000                 NaN      7.8
# 1       Detroit     USA     2770000                 NaN     15.4
# 2     Cleveland     USA      973000                 NaN      8.8
# 3     St. Louis     USA     1177000                 NaN      9.6
# 4    Pittsburgh     USA      602000                 NaN      6.3
#
#   Footprint/Cap (t CO2/cap)  ClusterID  Global ranking         City  \
# 0         26.1 &plusmn;13.0        373              12  New Orleans
# 1          25.5 &plusmn;5.6      16079              13      Detroit
# 2          24.7 &plusmn;9.0        726              17    Cleveland
# 3          24.1 &plusmn;8.2        448              19    St. Louis
# 4         24.0 &plusmn;10.4        753              21          NaN
#
#    Conservatism
# 0         -0.51
# 1         -0.73
# 2         -0.42
# 3         -0.52
# 4           NaN

# %% [markdown]
# ## 4.2 Put mayor support for climate change in as boolean

# %% [markdown]
# ## Merge and create boolean column

# %% [markdown]
# here are all the mayors and cities that signed support for the Paris Climate accord

# %%
mayor_paris
# Out:
#                 mayor_name       mayor_city
# 0    Trish Herrera Spencer      Alameda, CA
# 1            Peggy McQuaid       Albany, CA
# 2            Sharon Konopa       Albany, OR
# 3            Kathy Sheehan       Albany, NY
# 4               Tim Keller  Albuquerque, NM
# ..                     ...              ...
# 461            Brian Sager    Woodstock, IL
# 462        Joseph M. Petty    Worcester, MA
# 463             Mike Spano      Yonkers, NY
# 464      Jamael Tito Brown   Youngstown, OH
# 465        Lois Richardson    Ypsilanti, MI
#
# [466 rows x 2 columns]

# %% [markdown]
# Take the state off the 'mayor_city' column to set up for merge

# %%
if len(mayor_paris['mayor_city'][0]) >= 8:
    mayor_paris['mayor_city'] = mayor_paris['mayor_city'].str[:-4]
mayor_paris
# Out:
#                 mayor_name   mayor_city
# 0    Trish Herrera Spencer      Alameda
# 1            Peggy McQuaid       Albany
# 2            Sharon Konopa       Albany
# 3            Kathy Sheehan       Albany
# 4               Tim Keller  Albuquerque
# ..                     ...          ...
# 461            Brian Sager    Woodstock
# 462        Joseph M. Petty    Worcester
# 463             Mike Spano      Yonkers
# 464      Jamael Tito Brown   Youngstown
# 465        Lois Richardson    Ypsilanti
#
# [466 rows x 2 columns]

# %% [markdown]
# combine mayor_paris and comb_1

# %%
city_dataset = pd.merge(comb_1, mayor_paris, how='left', left_on = 'Urban Cluster', right_on = 'mayor_city')
city_dataset
# Out:
#                     Urban Cluster Country  Population  Footprint (Mt CO2)  \
# 0                     New Orleans     USA      596000                 NaN
# 1                         Detroit     USA     2770000                 NaN
# 2                       Cleveland     USA      973000                 NaN
# 3                       St. Louis     USA     1177000                 NaN
# 4                      Pittsburgh     USA      602000                 NaN
# ..                            ...     ...         ...                 ...
# 111  Unknown city at lat/lon 40.3     USA      253000                 NaN
# 112                   Bakersfield     USA      446000                 NaN
# 113      Riverside-San Bernardino     USA      166000                 NaN
# 114  Unknown city at lat/lon 33.5     USA      193000                 NaN
# 115  Unknown city at lat/lon 27.3     USA      170000                 NaN
#
#      1StdDev Footprint/Cap (t CO2/cap)  ClusterID  Global ranking  \
# 0        7.8         26.1 &plusmn;13.0        373              12
# 1       15.4          25.5 &plusmn;5.6      16079              13
# 2        8.8          24.7 &plusmn;9.0        726              17
# 3        9.6          24.1 &plusmn;8.2        448              19
# 4        6.3         24.0 &plusmn;10.4        753              21
# ..       ...                       ...        ...             ...
# 111      2.1          11.0 &plusmn;8.2        193             330
# 112      2.9          11.0 &plusmn;6.5         30             331
# 113      1.4          10.9 &plusmn;8.7         49             335
# 114      1.3           9.6 &plusmn;6.9         39             425
# 115      0.8           9.2 &plusmn;5.0        550             471
#
#             City  Conservatism       mayor_name   mayor_city
# 0    New Orleans         -0.51  LaToya Cantrell  New Orleans
# 1        Detroit         -0.73      Mike Duggan      Detroit
# 2      Cleveland         -0.42    Frank Jackson    Cleveland
# 3      St. Louis         -0.52     Lyda Krewson    St. Louis
# 4            NaN           NaN   William Peduto   Pittsburgh
# ..           ...           ...              ...          ...
# 111          NaN           NaN              NaN          NaN
# 112          NaN           NaN              NaN          NaN
# 113          NaN           NaN              NaN          NaN
# 114          NaN           NaN              NaN          NaN
# 115          NaN           NaN              NaN          NaN
#
# [116 rows x 12 columns]

# %% [markdown]
# create boolean column on whether the cities mayor signed support

# %%
city_dataset['supports_paris'] = city_dataset['Urban Cluster'] == city_dataset['mayor_city']
city_dataset
# Out:
#                     Urban Cluster Country  Population  Footprint (Mt CO2)  \
# 0                     New Orleans     USA      596000                 NaN
# 1                         Detroit     USA     2770000                 NaN
# 2                       Cleveland     USA      973000                 NaN
# 3                       St. Louis     USA     1177000                 NaN
# 4                      Pittsburgh     USA      602000                 NaN
# ..                            ...     ...         ...                 ...
# 111  Unknown city at lat/lon 40.3     USA      253000                 NaN
# 112                   Bakersfield     USA      446000                 NaN
# 113      Riverside-San Bernardino     USA      166000                 NaN
# 114  Unknown city at lat/lon 33.5     USA      193000                 NaN
# 115  Unknown city at lat/lon 27.3     USA      170000                 NaN
#
#      1StdDev Footprint/Cap (t CO2/cap)  ClusterID  Global ranking  \
# 0        7.8         26.1 &plusmn;13.0        373              12
# 1       15.4          25.5 &plusmn;5.6      16079              13
# 2        8.8          24.7 &plusmn;9.0        726              17
# 3        9.6          24.1 &plusmn;8.2        448              19
# 4        6.3         24.0 &plusmn;10.4        753              21
# ..       ...                       ...        ...             ...
# 111      2.1          11.0 &plusmn;8.2        193             330
# 112      2.9          11.0 &plusmn;6.5         30             331
# 113      1.4          10.9 &plusmn;8.7         49             335
# 114      1.3           9.6 &plusmn;6.9         39             425
# 115      0.8           9.2 &plusmn;5.0        550             471
#
#             City  Conservatism       mayor_name   mayor_city  supports_paris
# 0    New Orleans         -0.51  LaToya Cantrell  New Orleans            True
# 1        Detroit         -0.73      Mike Duggan      Detroit            True
# 2      Cleveland         -0.42    Frank Jackson    Cleveland            True
# 3      St. Louis         -0.52     Lyda Krewson    St. Louis            True
# 4            NaN           NaN   William Peduto   Pittsburgh            True
# ..           ...           ...              ...          ...             ...
# 111          NaN           NaN              NaN          NaN           False
# 112          NaN           NaN              NaN          NaN           False
# 113          NaN           NaN              NaN          NaN           False
# 114          NaN           NaN              NaN          NaN           False
# 115          NaN           NaN              NaN          NaN           False
#
# [116 rows x 13 columns]

# %% [markdown]
# rename and reduce the number of columns

# %%
if 'Urban Cluster' in city_dataset.columns:
    city_dataset = city_dataset[['Urban Cluster', 'mayor_name','Footprint/Cap (t CO2/cap)', 'Conservatism', 'supports_paris']]
    city_dataset = city_dataset.rename(columns = {'Urban Cluster': 'city', 'Footprint/Cap (t CO2/cap)':'CO2_per_capita', 'Conservatism':'conservatism' })
city_dataset
# Out:
#                              city       mayor_name     CO2_per_capita  \
# 0                     New Orleans  LaToya Cantrell  26.1 &plusmn;13.0
# 1                         Detroit      Mike Duggan   25.5 &plusmn;5.6
# 2                       Cleveland    Frank Jackson   24.7 &plusmn;9.0
# 3                       St. Louis     Lyda Krewson   24.1 &plusmn;8.2
# 4                      Pittsburgh   William Peduto  24.0 &plusmn;10.4
# ..                            ...              ...                ...
# 111  Unknown city at lat/lon 40.3              NaN   11.0 &plusmn;8.2
# 112                   Bakersfield              NaN   11.0 &plusmn;6.5
# 113      Riverside-San Bernardino              NaN   10.9 &plusmn;8.7
# 114  Unknown city at lat/lon 33.5              NaN    9.6 &plusmn;6.9
# 115  Unknown city at lat/lon 27.3              NaN    9.2 &plusmn;5.0
#
#      conservatism  supports_paris
# 0           -0.51            True
# 1           -0.73            True
# 2           -0.42            True
# 3           -0.52            True
# 4             NaN            True
# ..            ...             ...
# 111           NaN           False
# 112           NaN           False
# 113           NaN           False
# 114           NaN           False
# 115           NaN           False
#
# [116 rows x 5 columns]

# %% [markdown]
# ## Correct for cities from city_partisan that didn't merge

# %% [markdown]
# now I want to bring back the city_partisan_lost list

# %%
city_partisan_lost
# Out:
# ['Mesa',
#  'Virginia Beach',
#  'Arlington',
#  'Anaheim',
#  'Aurora',
#  'Anchorage',
#  'Fort Worth',
#  'Lexington',
#  'Riverside',
#  'Santa Ana',
#  'Long Beach',
#  'Honolulu',
#  'Newark',
#  'Pittrburgh',
#  'St. Paul',
#  'Washington',
#  'San Francisco']

# %% [markdown]
# In this we see Pittsburgh is spelled wrong and Washington for Washington D.C. is spelled differently when compared to the main dataset

# %%
print(city_partisan_lost[-2], city_partisan_lost[-4])
print(city_dataset.iloc[4,0], city_dataset.iloc[40,0])
# Out:
# Washington Pittrburgh
# Pittsburgh Washington D.C.

# %% [markdown]
# This is why the two cities didn't merge!
# I will create a sub datadrame with just these values from city_partisan and merge with city_datset to get their conservatism score in the city_dataset

# %%
sub_city_partisan = city_partisan.loc[[48, 65]]
sub_city_partisan = sub_city_partisan.rename(columns = {'City':'city', 'Conservatism': 'conservatism'})
sub_city_partisan
# Out:
#           city  conservatism
# 48  Pittrburgh         -0.49
# 65  Washington         -0.93

# %% [markdown]
# Change their spelling

# %%
sub_city_partisan['city'].replace({'Pittrburgh': 'Pittsburgh', 'Washington': 'Washington D.C.'}, inplace = True)
sub_city_partisan
# Out:
#                city  conservatism
# 48       Pittsburgh         -0.49
# 65  Washington D.C.         -0.93

# %% [markdown]
# merge

# %%
city_dataset = pd.merge(city_dataset, sub_city_partisan, how='left', left_on = 'city', right_on = 'city')
city_dataset
# Out:
#                              city       mayor_name     CO2_per_capita  \
# 0                     New Orleans  LaToya Cantrell  26.1 &plusmn;13.0
# 1                         Detroit      Mike Duggan   25.5 &plusmn;5.6
# 2                       Cleveland    Frank Jackson   24.7 &plusmn;9.0
# 3                       St. Louis     Lyda Krewson   24.1 &plusmn;8.2
# 4                      Pittsburgh   William Peduto  24.0 &plusmn;10.4
# ..                            ...              ...                ...
# 111  Unknown city at lat/lon 40.3              NaN   11.0 &plusmn;8.2
# 112                   Bakersfield              NaN   11.0 &plusmn;6.5
# 113      Riverside-San Bernardino              NaN   10.9 &plusmn;8.7
# 114  Unknown city at lat/lon 33.5              NaN    9.6 &plusmn;6.9
# 115  Unknown city at lat/lon 27.3              NaN    9.2 &plusmn;5.0
#
#      conservatism_x  supports_paris  conservatism_y
# 0             -0.51            True             NaN
# 1             -0.73            True             NaN
# 2             -0.42            True             NaN
# 3             -0.52            True             NaN
# 4               NaN            True           -0.49
# ..              ...             ...             ...
# 111             NaN           False             NaN
# 112             NaN           False             NaN
# 113             NaN           False             NaN
# 114             NaN           False             NaN
# 115             NaN           False             NaN
#
# [116 rows x 6 columns]

# %%
city_dataset
# Out:
#                              city       mayor_name     CO2_per_capita  \
# 0                     New Orleans  LaToya Cantrell  26.1 &plusmn;13.0
# 1                         Detroit      Mike Duggan   25.5 &plusmn;5.6
# 2                       Cleveland    Frank Jackson   24.7 &plusmn;9.0
# 3                       St. Louis     Lyda Krewson   24.1 &plusmn;8.2
# 4                      Pittsburgh   William Peduto  24.0 &plusmn;10.4
# ..                            ...              ...                ...
# 111  Unknown city at lat/lon 40.3              NaN   11.0 &plusmn;8.2
# 112                   Bakersfield              NaN   11.0 &plusmn;6.5
# 113      Riverside-San Bernardino              NaN   10.9 &plusmn;8.7
# 114  Unknown city at lat/lon 33.5              NaN    9.6 &plusmn;6.9
# 115  Unknown city at lat/lon 27.3              NaN    9.2 &plusmn;5.0
#
#      conservatism_x  supports_paris  conservatism_y
# 0             -0.51            True             NaN
# 1             -0.73            True             NaN
# 2             -0.42            True             NaN
# 3             -0.52            True             NaN
# 4               NaN            True           -0.49
# ..              ...             ...             ...
# 111             NaN           False             NaN
# 112             NaN           False             NaN
# 113             NaN           False             NaN
# 114             NaN           False             NaN
# 115             NaN           False             NaN
#
# [116 rows x 6 columns]

# %% [markdown]
# clean the merge

# %%
if 'conservatism_y' in city_dataset.columns:
    city_dataset.conservatism_x.fillna(city_dataset.conservatism_y, inplace = True)
    city_dataset.drop(['conservatism_y'], axis = 1, inplace = True)
city_dataset = city_dataset.rename(columns={'conservatism_x': 'conservatism'})
city_dataset.head()
# Out:
#           city       mayor_name     CO2_per_capita  conservatism  \
# 0  New Orleans  LaToya Cantrell  26.1 &plusmn;13.0         -0.51
# 1      Detroit      Mike Duggan   25.5 &plusmn;5.6         -0.73
# 2    Cleveland    Frank Jackson   24.7 &plusmn;9.0         -0.42
# 3    St. Louis     Lyda Krewson   24.1 &plusmn;8.2         -0.52
# 4   Pittsburgh   William Peduto  24.0 &plusmn;10.4         -0.49
#
#    supports_paris
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True

# %% [markdown]
# ## Final after Merge

# %%
city_dataset
# Out:
#                              city       mayor_name     CO2_per_capita  \
# 0                     New Orleans  LaToya Cantrell  26.1 &plusmn;13.0
# 1                         Detroit      Mike Duggan   25.5 &plusmn;5.6
# 2                       Cleveland    Frank Jackson   24.7 &plusmn;9.0
# 3                       St. Louis     Lyda Krewson   24.1 &plusmn;8.2
# 4                      Pittsburgh   William Peduto  24.0 &plusmn;10.4
# ..                            ...              ...                ...
# 111  Unknown city at lat/lon 40.3              NaN   11.0 &plusmn;8.2
# 112                   Bakersfield              NaN   11.0 &plusmn;6.5
# 113      Riverside-San Bernardino              NaN   10.9 &plusmn;8.7
# 114  Unknown city at lat/lon 33.5              NaN    9.6 &plusmn;6.9
# 115  Unknown city at lat/lon 27.3              NaN    9.2 &plusmn;5.0
#
#      conservatism  supports_paris
# 0           -0.51            True
# 1           -0.73            True
# 2           -0.42            True
# 3           -0.52            True
# 4           -0.49            True
# ..            ...             ...
# 111           NaN           False
# 112           NaN           False
# 113           NaN           False
# 114           NaN           False
# 115           NaN           False
#
# [116 rows x 5 columns]

# %% [markdown]
# # 5. Clean merged dataset and add Mayor Political Party

# %% [markdown]
# eliminate all rows that don't have a conservatism scale.

# %%
city_dataset = city_dataset.loc[city_dataset['conservatism'].notna()]
city_dataset.head()
# Out:
#           city       mayor_name     CO2_per_capita  conservatism  \
# 0  New Orleans  LaToya Cantrell  26.1 &plusmn;13.0         -0.51
# 1      Detroit      Mike Duggan   25.5 &plusmn;5.6         -0.73
# 2    Cleveland    Frank Jackson   24.7 &plusmn;9.0         -0.42
# 3    St. Louis     Lyda Krewson   24.1 &plusmn;8.2         -0.52
# 4   Pittsburgh   William Peduto  24.0 &plusmn;10.4         -0.49
#
#    supports_paris
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True

# %% [markdown]
# split the 'CO2_per_capita' column into 2 with 'plus_minus' as the other column

# %%
pd.options.mode.chained_assignment = None
city_dataset['CO2_per_cap'] = city_dataset['CO2_per_capita'].str.split(' &plusmn;').str[0]
city_dataset['plus_minus'] = city_dataset['CO2_per_capita'].str.split(' &plusmn;').str[1]
city_dataset
# Out:
#                  city          mayor_name     CO2_per_capita  conservatism  \
# 0         New Orleans     LaToya Cantrell  26.1 &plusmn;13.0         -0.51
# 1             Detroit         Mike Duggan   25.5 &plusmn;5.6         -0.73
# 2           Cleveland       Frank Jackson   24.7 &plusmn;9.0         -0.42
# 3           St. Louis        Lyda Krewson   24.1 &plusmn;8.2         -0.52
# 4          Pittsburgh      William Peduto  24.0 &plusmn;10.4         -0.49
# 5              Toledo  Wade Kapszukiewicz  22.8 &plusmn;13.5         -0.17
# 6         Kansas City       Quinton Lucas   22.6 &plusmn;7.4         -0.38
# 8          Cincinnati        John Cranley   22.6 &plusmn;8.9         -0.22
# 9               Tulsa                 NaN  22.6 &plusmn;10.3          0.07
# 12        Minneapolis          Jacob Frey   21.8 &plusmn;6.4         -0.77
# 14         Louisville        Greg Fischer   21.5 &plusmn;8.6         -0.10
# 16            Wichita                 NaN  21.3 &plusmn;11.1         -0.03
# 19            Chicago      Lori Lightfoot   21.1 &plusmn;5.1         -0.63
# 22      Oklahoma City                 NaN   20.8 &plusmn;8.9          0.26
# 23            Memphis      Jim Strickland   20.8 &plusmn;9.5         -0.33
# 24       Indianapolis      Joseph Hogsett   20.6 &plusmn;5.7         -0.12
# 26          Milwaukee         Tom Barrett   20.4 &plusmn;8.9         -0.26
# 29          Baltimore       Bernard Young   20.2 &plusmn;9.1         -0.66
# 30              Omaha                 NaN   19.9 &plusmn;8.8          0.08
# 31           Columbus      Andrew Ginther   19.8 &plusmn;8.5         -0.26
# 33            Buffalo         Byron Brown  19.8 &plusmn;10.0         -0.66
# 34       Philadelphia          Jim Kenney   19.5 &plusmn;5.4         -0.52
# 35             Denver     Michael Hancock   19.4 &plusmn;6.1         -0.48
# 36            Oakland        Libby Schaaf  19.3 &plusmn;10.6         -0.87
# 39             Boston      Martin J Walsh   19.0 &plusmn;8.4         -0.81
# 40    Washington D.C.       Muriel Bowser   19.0 &plusmn;4.5         -0.93
# 43            Atlanta      Keisha Bottoms   18.7 &plusmn;5.0         -0.48
# 50   Colorado Springs                 NaN   17.8 &plusmn;9.9          0.23
# 52          Nashville         John Cooper   17.6 &plusmn;9.6         -0.02
# 53           San Jose        Sam Liccardo   17.5 &plusmn;4.9         -0.32
# 56            Seattle        Jenny Durkan   17.3 &plusmn;5.6         -0.87
# 59           New York      Bill de Blasio   17.1 &plusmn;5.5         -0.66
# 61             Tucson       Regina Romero   17.1 &plusmn;7.6         -0.23
# 62        Albuquerque          Tim Keller   17.0 &plusmn;9.0         -0.23
# 63       Jacksonville                 NaN   17.0 &plusmn;6.3          0.18
# 66           Portland     Ethan Strimling   16.7 &plusmn;8.0         -0.59
# 67           Portland         Ted Wheeler   16.7 &plusmn;8.0         -0.59
# 72     Corpus Christi                 NaN  16.6 &plusmn;10.2         -0.01
# 74             Dallas        Eric Johnson   16.5 &plusmn;3.4         -0.23
# 82              Miami      Francis Suarez   16.0 &plusmn;4.4         -0.43
# 84            Phoenix        Kate Gallego   15.9 &plusmn;4.6         -0.04
# 90              Tampa         Jane Castor   15.3 &plusmn;6.3         -0.16
# 91        San Antonio       Ron Nirenberg   15.2 &plusmn;4.9         -0.01
# 92             Austin         Steve Adler   15.0 &plusmn;5.1         -0.53
# 95            Raleigh     Nancy McFarlane   14.7 &plusmn;7.1         -0.29
# 96            Houston    Sylvester Turner   14.6 &plusmn;4.0         -0.17
# 97        Los Angeles       Eric Garcetti   14.6 &plusmn;3.2         -0.49
# 98            El Paso                 NaN   14.6 &plusmn;8.5         -0.07
# 99          Charlotte            Vi Lyles   14.5 &plusmn;7.5         -0.17
# 100         San Diego     Kevin Faulconer   14.5 &plusmn;4.4         -0.36
# 103        Sacramento   Darrell Steinberg   14.2 &plusmn;4.9         -0.33
# 106            Fresno                 NaN   13.3 &plusmn;5.5          0.00
# 107         Las Vegas                 NaN   12.3 &plusmn;4.8         -0.03
#
#      supports_paris CO2_per_cap plus_minus
# 0              True        26.1       13.0
# 1              True        25.5        5.6
# 2              True        24.7        9.0
# 3              True        24.1        8.2
# 4              True        24.0       10.4
# 5              True        22.8       13.5
# 6              True        22.6        7.4
# 8              True        22.6        8.9
# 9             False        22.6       10.3
# 12             True        21.8        6.4
# 14             True        21.5        8.6
# 16            False        21.3       11.1
# 19             True        21.1        5.1
# 22            False        20.8        8.9
# 23             True        20.8        9.5
# 24             True        20.6        5.7
# 26             True        20.4        8.9
# 29             True        20.2        9.1
# 30            False        19.9        8.8
# 31             True        19.8        8.5
# 33             True        19.8       10.0
# 34             True        19.5        5.4
# 35             True        19.4        6.1
# 36             True        19.3       10.6
# 39             True        19.0        8.4
# 40             True        19.0        4.5
# 43             True        18.7        5.0
# 50            False        17.8        9.9
# 52             True        17.6        9.6
# 53             True        17.5        4.9
# 56             True        17.3        5.6
# 59             True        17.1        5.5
# 61             True        17.1        7.6
# 62             True        17.0        9.0
# 63            False        17.0        6.3
# 66             True        16.7        8.0
# 67             True        16.7        8.0
# 72            False        16.6       10.2
# 74             True        16.5        3.4
# 82             True        16.0        4.4
# 84             True        15.9        4.6
# 90             True        15.3        6.3
# 91             True        15.2        4.9
# 92             True        15.0        5.1
# 95             True        14.7        7.1
# 96             True        14.6        4.0
# 97             True        14.6        3.2
# 98            False        14.6        8.5
# 99             True        14.5        7.5
# 100            True        14.5        4.4
# 103            True        14.2        4.9
# 106           False        13.3        5.5
# 107           False        12.3        4.8

# %%
pd.options.mode.chained_assignment = 'warn'
city_dataset = city_dataset[['city', 'mayor_name', 'CO2_per_cap', 'plus_minus', 'conservatism', 'supports_paris']]
city_dataset
# Out:
#                  city          mayor_name CO2_per_cap plus_minus  \
# 0         New Orleans     LaToya Cantrell        26.1       13.0
# 1             Detroit         Mike Duggan        25.5        5.6
# 2           Cleveland       Frank Jackson        24.7        9.0
# 3           St. Louis        Lyda Krewson        24.1        8.2
# 4          Pittsburgh      William Peduto        24.0       10.4
# 5              Toledo  Wade Kapszukiewicz        22.8       13.5
# 6         Kansas City       Quinton Lucas        22.6        7.4
# 8          Cincinnati        John Cranley        22.6        8.9
# 9               Tulsa                 NaN        22.6       10.3
# 12        Minneapolis          Jacob Frey        21.8        6.4
# 14         Louisville        Greg Fischer        21.5        8.6
# 16            Wichita                 NaN        21.3       11.1
# 19            Chicago      Lori Lightfoot        21.1        5.1
# 22      Oklahoma City                 NaN        20.8        8.9
# 23            Memphis      Jim Strickland        20.8        9.5
# 24       Indianapolis      Joseph Hogsett        20.6        5.7
# 26          Milwaukee         Tom Barrett        20.4        8.9
# 29          Baltimore       Bernard Young        20.2        9.1
# 30              Omaha                 NaN        19.9        8.8
# 31           Columbus      Andrew Ginther        19.8        8.5
# 33            Buffalo         Byron Brown        19.8       10.0
# 34       Philadelphia          Jim Kenney        19.5        5.4
# 35             Denver     Michael Hancock        19.4        6.1
# 36            Oakland        Libby Schaaf        19.3       10.6
# 39             Boston      Martin J Walsh        19.0        8.4
# 40    Washington D.C.       Muriel Bowser        19.0        4.5
# 43            Atlanta      Keisha Bottoms        18.7        5.0
# 50   Colorado Springs                 NaN        17.8        9.9
# 52          Nashville         John Cooper        17.6        9.6
# 53           San Jose        Sam Liccardo        17.5        4.9
# 56            Seattle        Jenny Durkan        17.3        5.6
# 59           New York      Bill de Blasio        17.1        5.5
# 61             Tucson       Regina Romero        17.1        7.6
# 62        Albuquerque          Tim Keller        17.0        9.0
# 63       Jacksonville                 NaN        17.0        6.3
# 66           Portland     Ethan Strimling        16.7        8.0
# 67           Portland         Ted Wheeler        16.7        8.0
# 72     Corpus Christi                 NaN        16.6       10.2
# 74             Dallas        Eric Johnson        16.5        3.4
# 82              Miami      Francis Suarez        16.0        4.4
# 84            Phoenix        Kate Gallego        15.9        4.6
# 90              Tampa         Jane Castor        15.3        6.3
# 91        San Antonio       Ron Nirenberg        15.2        4.9
# 92             Austin         Steve Adler        15.0        5.1
# 95            Raleigh     Nancy McFarlane        14.7        7.1
# 96            Houston    Sylvester Turner        14.6        4.0
# 97        Los Angeles       Eric Garcetti        14.6        3.2
# 98            El Paso                 NaN        14.6        8.5
# 99          Charlotte            Vi Lyles        14.5        7.5
# 100         San Diego     Kevin Faulconer        14.5        4.4
# 103        Sacramento   Darrell Steinberg        14.2        4.9
# 106            Fresno                 NaN        13.3        5.5
# 107         Las Vegas                 NaN        12.3        4.8
#
#      conservatism  supports_paris
# 0           -0.51            True
# 1           -0.73            True
# 2           -0.42            True
# 3           -0.52            True
# 4           -0.49            True
# 5           -0.17            True
# 6           -0.38            True
# 8           -0.22            True
# 9            0.07           False
# 12          -0.77            True
# 14          -0.10            True
# 16          -0.03           False
# 19          -0.63            True
# 22           0.26           False
# 23          -0.33            True
# 24          -0.12            True
# 26          -0.26            True
# 29          -0.66            True
# 30           0.08           False
# 31          -0.26            True
# 33          -0.66            True
# 34          -0.52            True
# 35          -0.48            True
# 36          -0.87            True
# 39          -0.81            True
# 40          -0.93            True
# 43          -0.48            True
# 50           0.23           False
# 52          -0.02            True
# 53          -0.32            True
# 56          -0.87            True
# 59          -0.66            True
# 61          -0.23            True
# 62          -0.23            True
# 63           0.18           False
# 66          -0.59            True
# 67          -0.59            True
# 72          -0.01           False
# 74          -0.23            True
# 82          -0.43            True
# 84          -0.04            True
# 90          -0.16            True
# 91          -0.01            True
# 92          -0.53            True
# 95          -0.29            True
# 96          -0.17            True
# 97          -0.49            True
# 98          -0.07           False
# 99          -0.17            True
# 100         -0.36            True
# 103         -0.33            True
# 106          0.00           False
# 107         -0.03           False

# %% [markdown]
# create last column for mayor political party

# %%
city_dataset['mayor_political_party'] = np.nan
city_dataset.head()
# Out:
#           city       mayor_name CO2_per_cap plus_minus  conservatism  \
# 0  New Orleans  LaToya Cantrell        26.1       13.0         -0.51
# 1      Detroit      Mike Duggan        25.5        5.6         -0.73
# 2    Cleveland    Frank Jackson        24.7        9.0         -0.42
# 3    St. Louis     Lyda Krewson        24.1        8.2         -0.52
# 4   Pittsburgh   William Peduto        24.0       10.4         -0.49
#
#    supports_paris  mayor_political_party
# 0            True                    NaN
# 1            True                    NaN
# 2            True                    NaN
# 3            True                    NaN
# 4            True                    NaN

# %% [markdown]
# Remove duplicate cities

# %%
city_dataset['city'].duplicated(keep = False)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 8      False
# 9      False
# 12     False
# 14     False
# 16     False
# 19     False
# 22     False
# 23     False
# 24     False
# 26     False
# 29     False
# 30     False
# 31     False
# 33     False
# 34     False
# 35     False
# 36     False
# 39     False
# 40     False
# 43     False
# 50     False
# 52     False
# 53     False
# 56     False
# 59     False
# 61     False
# 62     False
# 63     False
# 66      True
# 67      True
# 72     False
# 74     False
# 82     False
# 84     False
# 90     False
# 91     False
# 92     False
# 95     False
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# 103    False
# 106    False
# 107    False
# Name: city, dtype: bool

# %% [markdown]
# Portland only one what was a duplicate

# %%
city_dataset.loc[[66, 67]]
# Out:
#         city       mayor_name CO2_per_cap plus_minus  conservatism  \
# 66  Portland  Ethan Strimling        16.7        8.0         -0.59
# 67  Portland      Ted Wheeler        16.7        8.0         -0.59
#
#     supports_paris  mayor_political_party
# 66            True                    NaN
# 67            True                    NaN

# %% [markdown]
# Only keep the Portland from Oregon.

# %%
if city_dataset['mayor_name'].loc[66] == 'Ethan Strimling':
    city_dataset.drop([66], inplace = True)
city_dataset
# Out:
#                  city          mayor_name CO2_per_cap plus_minus  \
# 0         New Orleans     LaToya Cantrell        26.1       13.0
# 1             Detroit         Mike Duggan        25.5        5.6
# 2           Cleveland       Frank Jackson        24.7        9.0
# 3           St. Louis        Lyda Krewson        24.1        8.2
# 4          Pittsburgh      William Peduto        24.0       10.4
# 5              Toledo  Wade Kapszukiewicz        22.8       13.5
# 6         Kansas City       Quinton Lucas        22.6        7.4
# 8          Cincinnati        John Cranley        22.6        8.9
# 9               Tulsa                 NaN        22.6       10.3
# 12        Minneapolis          Jacob Frey        21.8        6.4
# 14         Louisville        Greg Fischer        21.5        8.6
# 16            Wichita                 NaN        21.3       11.1
# 19            Chicago      Lori Lightfoot        21.1        5.1
# 22      Oklahoma City                 NaN        20.8        8.9
# 23            Memphis      Jim Strickland        20.8        9.5
# 24       Indianapolis      Joseph Hogsett        20.6        5.7
# 26          Milwaukee         Tom Barrett        20.4        8.9
# 29          Baltimore       Bernard Young        20.2        9.1
# 30              Omaha                 NaN        19.9        8.8
# 31           Columbus      Andrew Ginther        19.8        8.5
# 33            Buffalo         Byron Brown        19.8       10.0
# 34       Philadelphia          Jim Kenney        19.5        5.4
# 35             Denver     Michael Hancock        19.4        6.1
# 36            Oakland        Libby Schaaf        19.3       10.6
# 39             Boston      Martin J Walsh        19.0        8.4
# 40    Washington D.C.       Muriel Bowser        19.0        4.5
# 43            Atlanta      Keisha Bottoms        18.7        5.0
# 50   Colorado Springs                 NaN        17.8        9.9
# 52          Nashville         John Cooper        17.6        9.6
# 53           San Jose        Sam Liccardo        17.5        4.9
# 56            Seattle        Jenny Durkan        17.3        5.6
# 59           New York      Bill de Blasio        17.1        5.5
# 61             Tucson       Regina Romero        17.1        7.6
# 62        Albuquerque          Tim Keller        17.0        9.0
# 63       Jacksonville                 NaN        17.0        6.3
# 67           Portland         Ted Wheeler        16.7        8.0
# 72     Corpus Christi                 NaN        16.6       10.2
# 74             Dallas        Eric Johnson        16.5        3.4
# 82              Miami      Francis Suarez        16.0        4.4
# 84            Phoenix        Kate Gallego        15.9        4.6
# 90              Tampa         Jane Castor        15.3        6.3
# 91        San Antonio       Ron Nirenberg        15.2        4.9
# 92             Austin         Steve Adler        15.0        5.1
# 95            Raleigh     Nancy McFarlane        14.7        7.1
# 96            Houston    Sylvester Turner        14.6        4.0
# 97        Los Angeles       Eric Garcetti        14.6        3.2
# 98            El Paso                 NaN        14.6        8.5
# 99          Charlotte            Vi Lyles        14.5        7.5
# 100         San Diego     Kevin Faulconer        14.5        4.4
# 103        Sacramento   Darrell Steinberg        14.2        4.9
# 106            Fresno                 NaN        13.3        5.5
# 107         Las Vegas                 NaN        12.3        4.8
#
#      conservatism  supports_paris  mayor_political_party
# 0           -0.51            True                    NaN
# 1           -0.73            True                    NaN
# 2           -0.42            True                    NaN
# 3           -0.52            True                    NaN
# 4           -0.49            True                    NaN
# 5           -0.17            True                    NaN
# 6           -0.38            True                    NaN
# 8           -0.22            True                    NaN
# 9            0.07           False                    NaN
# 12          -0.77            True                    NaN
# 14          -0.10            True                    NaN
# 16          -0.03           False                    NaN
# 19          -0.63            True                    NaN
# 22           0.26           False                    NaN
# 23          -0.33            True                    NaN
# 24          -0.12            True                    NaN
# 26          -0.26            True                    NaN
# 29          -0.66            True                    NaN
# 30           0.08           False                    NaN
# 31          -0.26            True                    NaN
# 33          -0.66            True                    NaN
# 34          -0.52            True                    NaN
# 35          -0.48            True                    NaN
# 36          -0.87            True                    NaN
# 39          -0.81            True                    NaN
# 40          -0.93            True                    NaN
# 43          -0.48            True                    NaN
# 50           0.23           False                    NaN
# 52          -0.02            True                    NaN
# 53          -0.32            True                    NaN
# 56          -0.87            True                    NaN
# 59          -0.66            True                    NaN
# 61          -0.23            True                    NaN
# 62          -0.23            True                    NaN
# 63           0.18           False                    NaN
# 67          -0.59            True                    NaN
# 72          -0.01           False                    NaN
# 74          -0.23            True                    NaN
# 82          -0.43            True                    NaN
# 84          -0.04            True                    NaN
# 90          -0.16            True                    NaN
# 91          -0.01            True                    NaN
# 92          -0.53            True                    NaN
# 95          -0.29            True                    NaN
# 96          -0.17            True                    NaN
# 97          -0.49            True                    NaN
# 98          -0.07           False                    NaN
# 99          -0.17            True                    NaN
# 100         -0.36            True                    NaN
# 103         -0.33            True                    NaN
# 106          0.00           False                    NaN
# 107         -0.03           False                    NaN

# %% [markdown]
# Address missing mayor names

# %%
city_dataset[['city', 'mayor_name']].loc[city_dataset['mayor_name'].isna()]
# Out:
#                  city mayor_name
# 9               Tulsa        NaN
# 16            Wichita        NaN
# 22      Oklahoma City        NaN
# 30              Omaha        NaN
# 50   Colorado Springs        NaN
# 63       Jacksonville        NaN
# 72     Corpus Christi        NaN
# 98            El Paso        NaN
# 106            Fresno        NaN
# 107         Las Vegas        NaN

# %% [markdown]
# Create a dict for mayor names and a dataframe

# %%
mayor_names = {'Tulsa': 'Dewey F. Bartlett Jr.', 'Wichita': 'Jeff Longwell', 'Oklahoma City': 'Mick Cornett', 'Omaha': 'Jean Stothert',
              'Colorado Springs': 'John Suthers', 'Jacksonville': 'Lenny Curry', 'Corpus Christi': 'Joe McComb', 'El Paso': 'Dee Margo',
              'Fresno': 'Lee Brand', 'Las Vegas': 'Carolyn Goodman'}

key_list = list(mayor_names.keys())
val_list = list(mayor_names.values())
mayor_df = DataFrame(key_list)  
mayor_df['mayor_name'] = val_list
mayor_df.rename(columns = {0: 'city'}, inplace = True)
mayor_df
# Out:
#                city             mayor_name
# 0             Tulsa  Dewey F. Bartlett Jr.
# 1           Wichita          Jeff Longwell
# 2     Oklahoma City           Mick Cornett
# 3             Omaha          Jean Stothert
# 4  Colorado Springs           John Suthers
# 5      Jacksonville            Lenny Curry
# 6    Corpus Christi             Joe McComb
# 7           El Paso              Dee Margo
# 8            Fresno              Lee Brand
# 9         Las Vegas        Carolyn Goodman

# %% [markdown]
# merge missing mayors table this with the main dataset

# %%
city_dataset_merge = pd.merge(city_dataset, mayor_df, how='left', on = 'city')
city_dataset_merge

city_dataset_merge['mayor_name'] = city_dataset_merge['mayor_name_x'].fillna(city_dataset_merge['mayor_name_y'])
city_dataset_merge = city_dataset_merge.drop(['mayor_name_x', 'mayor_name_y'], axis = 1)
city_dataset = city_dataset_merge[['city', 'mayor_name','CO2_per_cap', 
                                   'plus_minus', 'conservatism', 'supports_paris',  'mayor_political_party']]
city_dataset
# Out:
#                 city             mayor_name CO2_per_cap plus_minus  \
# 0        New Orleans        LaToya Cantrell        26.1       13.0
# 1            Detroit            Mike Duggan        25.5        5.6
# 2          Cleveland          Frank Jackson        24.7        9.0
# 3          St. Louis           Lyda Krewson        24.1        8.2
# 4         Pittsburgh         William Peduto        24.0       10.4
# 5             Toledo     Wade Kapszukiewicz        22.8       13.5
# 6        Kansas City          Quinton Lucas        22.6        7.4
# 7         Cincinnati           John Cranley        22.6        8.9
# 8              Tulsa  Dewey F. Bartlett Jr.        22.6       10.3
# 9        Minneapolis             Jacob Frey        21.8        6.4
# 10        Louisville           Greg Fischer        21.5        8.6
# 11           Wichita          Jeff Longwell        21.3       11.1
# 12           Chicago         Lori Lightfoot        21.1        5.1
# 13     Oklahoma City           Mick Cornett        20.8        8.9
# 14           Memphis         Jim Strickland        20.8        9.5
# 15      Indianapolis         Joseph Hogsett        20.6        5.7
# 16         Milwaukee            Tom Barrett        20.4        8.9
# 17         Baltimore          Bernard Young        20.2        9.1
# 18             Omaha          Jean Stothert        19.9        8.8
# 19          Columbus         Andrew Ginther        19.8        8.5
# 20           Buffalo            Byron Brown        19.8       10.0
# 21      Philadelphia             Jim Kenney        19.5        5.4
# 22            Denver        Michael Hancock        19.4        6.1
# 23           Oakland           Libby Schaaf        19.3       10.6
# 24            Boston         Martin J Walsh        19.0        8.4
# 25   Washington D.C.          Muriel Bowser        19.0        4.5
# 26           Atlanta         Keisha Bottoms        18.7        5.0
# 27  Colorado Springs           John Suthers        17.8        9.9
# 28         Nashville            John Cooper        17.6        9.6
# 29          San Jose           Sam Liccardo        17.5        4.9
# 30           Seattle           Jenny Durkan        17.3        5.6
# 31          New York         Bill de Blasio        17.1        5.5
# 32            Tucson          Regina Romero        17.1        7.6
# 33       Albuquerque             Tim Keller        17.0        9.0
# 34      Jacksonville            Lenny Curry        17.0        6.3
# 35          Portland            Ted Wheeler        16.7        8.0
# 36    Corpus Christi             Joe McComb        16.6       10.2
# 37            Dallas           Eric Johnson        16.5        3.4
# 38             Miami         Francis Suarez        16.0        4.4
# 39           Phoenix           Kate Gallego        15.9        4.6
# 40             Tampa            Jane Castor        15.3        6.3
# 41       San Antonio          Ron Nirenberg        15.2        4.9
# 42            Austin            Steve Adler        15.0        5.1
# 43           Raleigh        Nancy McFarlane        14.7        7.1
# 44           Houston       Sylvester Turner        14.6        4.0
# 45       Los Angeles          Eric Garcetti        14.6        3.2
# 46           El Paso              Dee Margo        14.6        8.5
# 47         Charlotte               Vi Lyles        14.5        7.5
# 48         San Diego        Kevin Faulconer        14.5        4.4
# 49        Sacramento      Darrell Steinberg        14.2        4.9
# 50            Fresno              Lee Brand        13.3        5.5
# 51         Las Vegas        Carolyn Goodman        12.3        4.8
#
#     conservatism  supports_paris  mayor_political_party
# 0          -0.51            True                    NaN
# 1          -0.73            True                    NaN
# 2          -0.42            True                    NaN
# 3          -0.52            True                    NaN
# 4          -0.49            True                    NaN
# 5          -0.17            True                    NaN
# 6          -0.38            True                    NaN
# 7          -0.22            True                    NaN
# 8           0.07           False                    NaN
# 9          -0.77            True                    NaN
# 10         -0.10            True                    NaN
# 11         -0.03           False                    NaN
# 12         -0.63            True                    NaN
# 13          0.26           False                    NaN
# 14         -0.33            True                    NaN
# 15         -0.12            True                    NaN
# 16         -0.26            True                    NaN
# 17         -0.66            True                    NaN
# 18          0.08           False                    NaN
# 19         -0.26            True                    NaN
# 20         -0.66            True                    NaN
# 21         -0.52            True                    NaN
# 22         -0.48            True                    NaN
# 23         -0.87            True                    NaN
# 24         -0.81            True                    NaN
# 25         -0.93            True                    NaN
# 26         -0.48            True                    NaN
# 27          0.23           False                    NaN
# 28         -0.02            True                    NaN
# 29         -0.32            True                    NaN
# 30         -0.87            True                    NaN
# 31         -0.66            True                    NaN
# 32         -0.23            True                    NaN
# 33         -0.23            True                    NaN
# 34          0.18           False                    NaN
# 35         -0.59            True                    NaN
# 36         -0.01           False                    NaN
# 37         -0.23            True                    NaN
# 38         -0.43            True                    NaN
# 39         -0.04            True                    NaN
# 40         -0.16            True                    NaN
# 41         -0.01            True                    NaN
# 42         -0.53            True                    NaN
# 43         -0.29            True                    NaN
# 44         -0.17            True                    NaN
# 45         -0.49            True                    NaN
# 46         -0.07           False                    NaN
# 47         -0.17            True                    NaN
# 48         -0.36            True                    NaN
# 49         -0.33            True                    NaN
# 50          0.00           False                    NaN
# 51         -0.03           False                    NaN

# %% [markdown]
# After searching for possible sites to webscrape on, it will be easiest to fill in this column manually

# %% [markdown]
# export to a csv file with nan values to be filled in

# %%
city_dataset1 = city_dataset.sort_values('mayor_name')
city_dataset1.to_csv(r'/Users/joeskvarna/Desktop/Thesis/Data/city_dataset_fillin.csv', index = False)

# %% [markdown]
# Final dataset after filling in last column

# %%
city_dataset = pd.read_csv(path.join(DATA_DIR, 'city_dataset_reimport.csv'))
city_dataset
# Out:
#                 city             mayor_name  CO2_per_cap  plus_minus  \
# 0           Columbus         Andrew Ginther         19.8         8.5
# 1          Baltimore          Bernard Young         20.2         9.1
# 2           New York         Bill de Blasio         17.1         5.5
# 3            Buffalo            Byron Brown         19.8        10.0
# 4          Las Vegas        Carolyn Goodman         12.3         4.8
# 5         Sacramento      Darrell Steinberg         14.2         4.9
# 6            El Paso              Dee Margo         14.6         8.5
# 7              Tulsa  Dewey F. Bartlett Jr.         22.6        10.3
# 8        Los Angeles          Eric Garcetti         14.6         3.2
# 9             Dallas           Eric Johnson         16.5         3.4
# 10             Miami         Francis Suarez         16.0         4.4
# 11         Cleveland          Frank Jackson         24.7         9.0
# 12        Louisville           Greg Fischer         21.5         8.6
# 13       Minneapolis             Jacob Frey         21.8         6.4
# 14             Tampa            Jane Castor         15.3         6.3
# 15             Omaha          Jean Stothert         19.9         8.8
# 16           Wichita          Jeff Longwell         21.3        11.1
# 17           Seattle           Jenny Durkan         17.3         5.6
# 18      Philadelphia             Jim Kenney         19.5         5.4
# 19           Memphis         Jim Strickland         20.8         9.5
# 20    Corpus Christi             Joe McComb         16.6        10.2
# 21         Nashville            John Cooper         17.6         9.6
# 22        Cincinnati           John Cranley         22.6         8.9
# 23  Colorado Springs           John Suthers         17.8         9.9
# 24      Indianapolis         Joseph Hogsett         20.6         5.7
# 25           Phoenix           Kate Gallego         15.9         4.6
# 26           Atlanta         Keisha Bottoms         18.7         5.0
# 27         San Diego        Kevin Faulconer         14.5         4.4
# 28       New Orleans        LaToya Cantrell         26.1        13.0
# 29            Fresno              Lee Brand         13.3         5.5
# 30      Jacksonville            Lenny Curry         17.0         6.3
# 31           Oakland           Libby Schaaf         19.3        10.6
# 32           Chicago         Lori Lightfoot         21.1         5.1
# 33         St. Louis           Lyda Krewson         24.1         8.2
# 34            Boston         Martin J Walsh         19.0         8.4
# 35            Denver        Michael Hancock         19.4         6.1
# 36     Oklahoma City           Mick Cornett         20.8         8.9
# 37           Detroit            Mike Duggan         25.5         5.6
# 38   Washington D.C.          Muriel Bowser         19.0         4.5
# 39           Raleigh        Nancy McFarlane         14.7         7.1
# 40       Kansas City          Quinton Lucas         22.6         7.4
# 41            Tucson          Regina Romero         17.1         7.6
# 42       San Antonio          Ron Nirenberg         15.2         4.9
# 43          San Jose           Sam Liccardo         17.5         4.9
# 44            Austin            Steve Adler         15.0         5.1
# 45           Houston       Sylvester Turner         14.6         4.0
# 46          Portland            Ted Wheeler         16.7         8.0
# 47       Albuquerque             Tim Keller         17.0         9.0
# 48         Milwaukee            Tom Barrett         20.4         8.9
# 49         Charlotte               Vi Lyles         14.5         7.5
# 50            Toledo     Wade Kapszukiewicz         22.8        13.5
# 51        Pittsburgh         William Peduto         24.0        10.4
#
#     conservatism  supports_paris mayor_political_party
# 0          -0.26            True                     D
# 1          -0.66            True                     D
# 2          -0.66            True                     D
# 3          -0.66            True                     D
# 4          -0.03           False                     I
# 5          -0.33            True                     D
# 6          -0.07           False                     R
# 7           0.07           False                     R
# 8          -0.49            True                     D
# 9          -0.23            True                     D
# 10         -0.43            True                     R
# 11         -0.42            True                     D
# 12         -0.10            True                     D
# 13         -0.77            True                     D
# 14         -0.16            True                     D
# 15          0.08           False                     R
# 16         -0.03           False                     R
# 17         -0.87            True                     D
# 18         -0.52            True                     D
# 19         -0.33            True                     D
# 20         -0.01           False                     R
# 21         -0.02            True                     D
# 22         -0.22            True                     D
# 23          0.23           False                     R
# 24         -0.12            True                     D
# 25         -0.04            True                     D
# 26         -0.48            True                     D
# 27         -0.36            True                     R
# 28         -0.51            True                     D
# 29          0.00           False                     R
# 30          0.18           False                     R
# 31         -0.87            True                     D
# 32         -0.63            True                     D
# 33         -0.52            True                     D
# 34         -0.81            True                     D
# 35         -0.48            True                     D
# 36          0.26           False                     R
# 37         -0.73            True                     D
# 38         -0.93            True                     D
# 39         -0.29            True                     I
# 40         -0.38            True                     D
# 41         -0.23            True                     D
# 42         -0.01            True                     I
# 43         -0.32            True                     D
# 44         -0.53            True                     D
# 45         -0.17            True                     D
# 46         -0.59            True                     D
# 47         -0.23            True                     D
# 48         -0.26            True                     D
# 49         -0.17            True                     D
# 50         -0.17            True                     D
# 51         -0.49            True                     D

# %% [markdown]
# Save to path

# %%
city_dataset.to_csv('/Users/joeskvarna/Desktop/Thesis/Data/city_dataset.csv', index = False)
